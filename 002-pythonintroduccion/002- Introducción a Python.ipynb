# %% [markdown]
# Ejercicio 1: Variables y Operaciones\.

# %%
nombre = 'Elias'
edad = 20
ciudad = 'Buenos Aires'
print(f'Buenas, mi nombre es {nombre}, tengo {edad} años y vivo en {ciudad}.')

# %%
a = 134
b = 34

print('suma: ', a + b)
print('resta: ', a - b)
print('multiplicación: ', a * b)
print('división: ', a / b)

# %% [markdown]
# Ejercicio 2: Condicionales\.

# %%
edad = int(input("Ingresa su edad: "))
if edad >= 18:
    print("Sos mayor de edad.")
else:
    print("Sos menor de edad.")

# %% [markdown]
# Ejercicio 3: Listas y Bucles\.

# %%
numeros = [45, 67, 38, 36, 9]

for numero in numeros:
    print(numero)

suma = sum(numeros)
promedio = suma / len(numeros)
print("La suma de los números es:", suma)
print("El promedio de los números es:", promedio)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3813d2cc-44f4-46eb-97d8-eca37904fada' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
